# %%
# Install LibreOffice

# %%
import os  
  
def install_libreoffice():  
    try:  
        # Update the package list  
        os.system('sudo apt-get update')  
  
        # Install LibreOffice  
        os.system('sudo apt-get install -y libreoffice')  
  
        print("LibreOffice installation completed successfully.")  
    except Exception as e:  
        print(f"An error occurred: {e}")  
  
install_libreoffice()
# Out:
# Get:1 file:/var/nccl-repo-2.2.13-ga-cuda9.2  InRelease
# Ign:1 file:/var/nccl-repo-2.2.13-ga-cuda9.2  InRelease
# Get:2 file:/var/nccl-repo-2.2.13-ga-cuda9.2  Release [574 B]
# Hit:3 http://azure.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 file:/var/nccl-repo-2.2.13-ga-cuda9.2  Release [574 B]
# Hit:4 http://azure.archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:5 http://azure.archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:6 http://azure.archive.ubuntu.com/ubuntu focal-security InRelease
# Hit:7 https://packages.microsoft.com/repos/azure-cli focal InRelease
# Get:8 https://packages.microsoft.com/ubuntu/20.04/prod focal InRelease [3632 B]
# Get:9 https://nvidia.github.io/libnvidia-container/stable/ubuntu18.04/amd64  InRelease [1484 B]
# Hit:10 https://storage.googleapis.com/tensorflow-serving-apt stable InRelease
# Hit:11 https://nvidia.github.io/nvidia-container-runtime/stable/ubuntu18.04/amd64  InRelease
# Hit:12 https://nvidia.github.io/nvidia-docker/ubuntu18.04/amd64  InRelease
# Hit:14 https://apt.repos.intel.com/mkl all InRelease
# Hit:15 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:16 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:17 http://ppa.launchpad.net/git-core/ppa/ubuntu focal InRelease
# Fetched 5116 B in 31s (162 B/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   firebird3.0-common firebird3.0-common-doc firebird3.0-server-core
#   firebird3.0-utils fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu fonts-liberation fonts-liberation2 fonts-linuxlibertine
#   fonts-noto-core fonts-noto-extra fonts-noto-mono fonts-noto-ui-core
#   fonts-opensymbol fonts-sil-gentium fonts-sil-gentium-basic gstreamer1.0-gtk3
#   libabw-0.1-1 libapache-pom-java libboost-date-time1.71.0
#   libboost-filesystem1.71.0 libboost-iostreams1.71.0 libboost-locale1.71.0
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5
#   libcmis-0.5-5v5 libcolamd2 libcommons-logging-java libcommons-parent-java
#   libe-book-0.1-1 libel-api-java libeot0 libepubgen-0.1-1 libetonyek-0.1-1
#   libexttextcat-2.0-0 libexttextcat-data libfbclient2 libfreehand-0.1-1
#   libgpgmepp6 libhsqldb1.8.0-java libib-util libjsp-api-java libjuh-java
#   libjurt-java liblangtag-common liblangtag1 libmhash2 libmspub-0.1-1
#   libmwaw-0.3-3 libmysqlclient21 libmythes-1.2-0 libneon27-gnutls
#   libodfgen-0.1-1 liborcus-0.15-0 libpagemaker-0.0-0 libpoppler97 libpq5
#   libraptor2-0 librasqal3 librdf0 libreoffice-base libreoffice-base-core
#   libreoffice-base-drivers libreoffice-calc libreoffice-common
#   libreoffice-core libreoffice-draw libreoffice-gnome libreoffice-gtk3
#   libreoffice-impress libreoffice-java-common libreoffice-math
#   libreoffice-nlpsolver libreoffice-report-builder
#   libreoffice-report-builder-bin libreoffice-script-provider-bsh
#   libreoffice-script-provider-js libreoffice-script-provider-python
#   libreoffice-sdbc-firebird libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql
#   libreoffice-sdbc-postgresql libreoffice-style-colibre
#   libreoffice-style-elementary libreoffice-style-tango
#   libreoffice-wiki-publisher libreoffice-writer librevenge-0.0-0 libridl-java
#   libservlet-api-java libservlet3.1-java libsuitesparseconfig5 libtommath1
#   libuno-cppu3 libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libunoil-java libunoloader-java libvisio-0.1-1
#   libwebsocket-api-java libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4
#   libxmlsec1-nss libyajl2 lp-solve mysql-common poppler-data python3-uno
#   uno-libs-private ure
# Suggested packages:
#   firebird3.0-server firebird3.0-doc libavalon-framework-java
#   libcommons-logging-java-doc libexcalibur-logkit-java liblog4j1.2-java
#   java-virtual-machine libhsqldb1.8.0-java-gcj raptor2-utils rasqal-utils
#   librdf-storage-postgresql librdf-storage-mysql librdf-storage-sqlite
#   librdf-storage-virtuoso redland-utils cups-bsd firefox-esr | thunderbird
#   | firefox ghostscript gpa hyphen-hyphenation-patterns imagemagick
#   | graphicsmagick-imagemagick-compat libreoffice-grammarcheck
#   libreoffice-help libreoffice-l10n libreoffice-librelogo myspell-dictionary
#   mythes-thesaurus openclipart2-libreoffice | openclipart-libreoffice pstoedit
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   gstreamer1.0-plugins-ugly gstreamer1.0-plugins-bad gstreamer1.0-libav
#   libsane libofficebean-java libjtds-java libsqliteodbc | tdsodbc
#   | odbc-mdbtools libreoffice-evolution seahorse libreofficekit-data bluez
#   default-mysql-server | virtual-mysql-server postgresql tango-icon-theme
#   mediawiki poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   firebird3.0-common firebird3.0-common-doc firebird3.0-server-core
#   firebird3.0-utils fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu fonts-liberation fonts-liberation2 fonts-linuxlibertine
#   fonts-noto-core fonts-noto-extra fonts-noto-mono fonts-noto-ui-core
#   fonts-opensymbol fonts-sil-gentium fonts-sil-gentium-basic gstreamer1.0-gtk3
#   libabw-0.1-1 libapache-pom-java libboost-date-time1.71.0
#   libboost-filesystem1.71.0 libboost-iostreams1.71.0 libboost-locale1.71.0
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5
#   libcmis-0.5-5v5 libcolamd2 libcommons-logging-java libcommons-parent-java
#   libe-book-0.1-1 libel-api-java libeot0 libepubgen-0.1-1 libetonyek-0.1-1
#   libexttextcat-2.0-0 libexttextcat-data libfbclient2 libfreehand-0.1-1
#   libgpgmepp6 libhsqldb1.8.0-java libib-util libjsp-api-java libjuh-java
#   libjurt-java liblangtag-common liblangtag1 libmhash2 libmspub-0.1-1
#   libmwaw-0.3-3 libmysqlclient21 libmythes-1.2-0 libneon27-gnutls
#   libodfgen-0.1-1 liborcus-0.15-0 libpagemaker-0.0-0 libpoppler97 libpq5
#   libraptor2-0 librasqal3 librdf0 libreoffice libreoffice-base
#   libreoffice-base-core libreoffice-base-drivers libreoffice-calc
#   libreoffice-common libreoffice-core libreoffice-draw libreoffice-gnome
#   libreoffice-gtk3 libreoffice-impress libreoffice-java-common
#   libreoffice-math libreoffice-nlpsolver libreoffice-report-builder
#   libreoffice-report-builder-bin libreoffice-script-provider-bsh
#   libreoffice-script-provider-js libreoffice-script-provider-python
#   libreoffice-sdbc-firebird libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql
#   libreoffice-sdbc-postgresql libreoffice-style-colibre
#   libreoffice-style-elementary libreoffice-style-tango
#   libreoffice-wiki-publisher libreoffice-writer librevenge-0.0-0 libridl-java
#   libservlet-api-java libservlet3.1-java libsuitesparseconfig5 libtommath1
#   libuno-cppu3 libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libunoil-java libunoloader-java libvisio-0.1-1
#   libwebsocket-api-java libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4
#   libxmlsec1-nss libyajl2 lp-solve mysql-common poppler-data python3-uno
#   uno-libs-private ure
# 0 upgraded, 117 newly installed, 0 to remove and 164 not upgraded.
# Need to get 135 kB/205 MB of archives.
# After this operation, 821 MB of additional disk space will be used.
# Get:1 http://azure.archive.ubuntu.com/ubuntu focal/main amd64 libmspub-0.1-1 amd64 0.1.4-1build3 [135 kB]
# Fetched 135 kB in 0s (8615 kB/s)
# Selecting previously unselected package fonts-opensymbol.
# (Reading database ... 152450 files and directories currently installed.)
# Preparing to unpack .../000-fonts-opensymbol_2%3a102.11+LibO6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking fonts-opensymbol (2:102.11+LibO6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../001-libreoffice-style-colibre_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-style-colibre (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-style-tango.
# Preparing to unpack .../002-libreoffice-style-tango_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-style-tango (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../003-libuno-sal3_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libuno-sal3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../004-libuno-salhelpergcc3-3_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libuno-salhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libuno-cppu3.
# Preparing to unpack .../005-libuno-cppu3_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libuno-cppu3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package uno-libs-private.
# Preparing to unpack .../006-uno-libs-private_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking uno-libs-private (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package liblangtag-common.
# Preparing to unpack .../007-liblangtag-common_0.6.3-1_all.deb ...
# Unpacking liblangtag-common (0.6.3-1) ...
# Selecting previously unselected package liblangtag1:amd64.
# Preparing to unpack .../008-liblangtag1_0.6.3-1_amd64.deb ...
# Unpacking liblangtag1:amd64 (0.6.3-1) ...
# Selecting previously unselected package libuno-cppuhelpergcc3-3.
# Preparing to unpack .../009-libuno-cppuhelpergcc3-3_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libuno-cppuhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libuno-purpenvhelpergcc3-3.
# Preparing to unpack .../010-libuno-purpenvhelpergcc3-3_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libuno-purpenvhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package ure.
# Preparing to unpack .../011-ure_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking ure (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-common.
# Preparing to unpack .../012-libreoffice-common_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-common (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libboost-locale1.71.0:amd64.
# Preparing to unpack .../013-libboost-locale1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-locale1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libclucene-core1v5:amd64.
# Preparing to unpack .../014-libclucene-core1v5_2.3.3.4+dfsg-1build1_amd64.deb ...
# Unpacking libclucene-core1v5:amd64 (2.3.3.4+dfsg-1build1) ...
# Selecting previously unselected package libclucene-contribs1v5:amd64.
# Preparing to unpack .../015-libclucene-contribs1v5_2.3.3.4+dfsg-1build1_amd64.deb ...
# Unpacking libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1build1) ...
# Selecting previously unselected package libboost-date-time1.71.0:amd64.
# Preparing to unpack .../016-libboost-date-time1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-date-time1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libcmis-0.5-5v5.
# Preparing to unpack .../017-libcmis-0.5-5v5_0.5.2-1ubuntu1_amd64.deb ...
# Unpacking libcmis-0.5-5v5 (0.5.2-1ubuntu1) ...
# Selecting previously unselected package libeot0:amd64.
# Preparing to unpack .../018-libeot0_0.01-5_amd64.deb ...
# Unpacking libeot0:amd64 (0.01-5) ...
# Selecting previously unselected package libexttextcat-data.
# Preparing to unpack .../019-libexttextcat-data_3.4.5-1_all.deb ...
# Unpacking libexttextcat-data (3.4.5-1) ...
# Selecting previously unselected package libexttextcat-2.0-0:amd64.
# Preparing to unpack .../020-libexttextcat-2.0-0_3.4.5-1_amd64.deb ...
# Unpacking libexttextcat-2.0-0:amd64 (3.4.5-1) ...
# Selecting previously unselected package libgpgmepp6:amd64.
# Preparing to unpack .../021-libgpgmepp6_1.13.1-7ubuntu2.2_amd64.deb ...
# Unpacking libgpgmepp6:amd64 (1.13.1-7ubuntu2.2) ...
# Selecting previously unselected package libmythes-1.2-0:amd64.
# Preparing to unpack .../022-libmythes-1.2-0_2%3a1.2.4-3build1_amd64.deb ...
# Unpacking libmythes-1.2-0:amd64 (2:1.2.4-3build1) ...
# Selecting previously unselected package libneon27-gnutls:amd64.
# Preparing to unpack .../023-libneon27-gnutls_0.30.2-4_amd64.deb ...
# Unpacking libneon27-gnutls:amd64 (0.30.2-4) ...
# Selecting previously unselected package libboost-filesystem1.71.0:amd64.
# Preparing to unpack .../024-libboost-filesystem1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-filesystem1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package libboost-iostreams1.71.0:amd64.
# Preparing to unpack .../025-libboost-iostreams1.71.0_1.71.0-6ubuntu6_amd64.deb ...
# Unpacking libboost-iostreams1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Selecting previously unselected package liborcus-0.15-0:amd64.
# Preparing to unpack .../026-liborcus-0.15-0_0.15.3-3build2_amd64.deb ...
# Unpacking liborcus-0.15-0:amd64 (0.15.3-3build2) ...
# Selecting previously unselected package libpoppler97:amd64.
# Preparing to unpack .../027-libpoppler97_0.86.1-0ubuntu1.4_amd64.deb ...
# Unpacking libpoppler97:amd64 (0.86.1-0ubuntu1.4) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../028-librevenge-0.0-0_0.0.4-6ubuntu5_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu5) ...
# Selecting previously unselected package libxmlsec1-nss:amd64.
# Preparing to unpack .../029-libxmlsec1-nss_1.2.28-2_amd64.deb ...
# Unpacking libxmlsec1-nss:amd64 (1.2.28-2) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../030-libyajl2_2.1.0-3ubuntu0.20.04.1_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3ubuntu0.20.04.1) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../031-libraptor2-0_2.0.15-0ubuntu1.20.04.1_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu1.20.04.1) ...
# Selecting previously unselected package libmhash2:amd64.
# Preparing to unpack .../032-libmhash2_0.9.9.9-8_amd64.deb ...
# Unpacking libmhash2:amd64 (0.9.9.9-8) ...
# Selecting previously unselected package librasqal3:amd64.
# Preparing to unpack .../033-librasqal3_0.9.33-0.1_amd64.deb ...
# Unpacking librasqal3:amd64 (0.9.33-0.1) ...
# Selecting previously unselected package librdf0:amd64.
# Preparing to unpack .../034-librdf0_1.0.17-1.1ubuntu1_amd64.deb ...
# Unpacking librdf0:amd64 (1.0.17-1.1ubuntu1) ...
# Selecting previously unselected package libreoffice-core.
# Preparing to unpack .../035-libreoffice-core_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-core (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-base-core.
# Preparing to unpack .../036-libreoffice-base-core_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-base-core (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-base-drivers.
# Preparing to unpack .../037-libreoffice-base-drivers_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-base-drivers (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-base.
# Preparing to unpack .../038-libreoffice-base_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/dialog.xlc to /usr/lib/libreoffice/share/basic/dialog.xlc.noaccess by libreoffice-base', none removed.
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/script.xlc to /usr/lib/libreoffice/share/basic/script.xlc.noaccess by libreoffice-base', none removed.
# Unpacking libreoffice-base (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../039-poppler-data_0.4.9-2_all.deb ...
# Unpacking poppler-data (0.4.9-2) ...
# Selecting previously unselected package firebird3.0-common-doc.
# Preparing to unpack .../040-firebird3.0-common-doc_3.0.5.33220.ds4-1build2_all.deb ...
# Unpacking firebird3.0-common-doc (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package firebird3.0-common.
# Preparing to unpack .../041-firebird3.0-common_3.0.5.33220.ds4-1build2_all.deb ...
# Unpacking firebird3.0-common (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package libtommath1:amd64.
# Preparing to unpack .../042-libtommath1_1.2.0-3ubuntu0.1_amd64.deb ...
# Unpacking libtommath1:amd64 (1.2.0-3ubuntu0.1) ...
# Selecting previously unselected package libfbclient2:amd64.
# Preparing to unpack .../043-libfbclient2_3.0.5.33220.ds4-1build2_amd64.deb ...
# Unpacking libfbclient2:amd64 (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package libib-util:amd64.
# Preparing to unpack .../044-libib-util_3.0.5.33220.ds4-1build2_amd64.deb ...
# Unpacking libib-util:amd64 (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package firebird3.0-server-core:amd64.
# Preparing to unpack .../045-firebird3.0-server-core_3.0.5.33220.ds4-1build2_amd64.deb ...
# Unpacking firebird3.0-server-core:amd64 (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package firebird3.0-utils.
# Preparing to unpack .../046-firebird3.0-utils_3.0.5.33220.ds4-1build2_amd64.deb ...
# Unpacking firebird3.0-utils (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package fonts-crosextra-caladea.
# Preparing to unpack .../047-fonts-crosextra-caladea_20130214-2_all.deb ...
# Unpacking fonts-crosextra-caladea (20130214-2) ...
# Selecting previously unselected package fonts-crosextra-carlito.
# Preparing to unpack .../048-fonts-crosextra-carlito_20130920-1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1) ...
# Selecting previously unselected package fonts-dejavu.
# Preparing to unpack .../049-fonts-dejavu_2.37-1_all.deb ...
# Unpacking fonts-dejavu (2.37-1) ...
# Selecting previously unselected package fonts-liberation.
# Preparing to unpack .../050-fonts-liberation_1%3a1.07.4-11_all.deb ...
# Unpacking fonts-liberation (1:1.07.4-11) ...
# Selecting previously unselected package fonts-liberation2.
# Preparing to unpack .../051-fonts-liberation2_2.1.0-1_all.deb ...
# Unpacking fonts-liberation2 (2.1.0-1) ...
# Selecting previously unselected package fonts-linuxlibertine.
# Preparing to unpack .../052-fonts-linuxlibertine_5.3.0-4_all.deb ...
# Unpacking fonts-linuxlibertine (5.3.0-4) ...
# Selecting previously unselected package fonts-noto-core.
# Preparing to unpack .../053-fonts-noto-core_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-core (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-noto-extra.
# Preparing to unpack .../054-fonts-noto-extra_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-extra (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../055-fonts-noto-mono_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-noto-ui-core.
# Preparing to unpack .../056-fonts-noto-ui-core_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-ui-core (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-sil-gentium.
# Preparing to unpack .../057-fonts-sil-gentium_20081126%3a1.03-2_all.deb ...
# Unpacking fonts-sil-gentium (20081126:1.03-2) ...
# Selecting previously unselected package fonts-sil-gentium-basic.
# Preparing to unpack .../058-fonts-sil-gentium-basic_1.102-1_all.deb ...
# Unpacking fonts-sil-gentium-basic (1.102-1) ...
# Selecting previously unselected package gstreamer1.0-gtk3:amd64.
# Preparing to unpack .../059-gstreamer1.0-gtk3_1.16.3-0ubuntu1.2_amd64.deb ...
# Unpacking gstreamer1.0-gtk3:amd64 (1.16.3-0ubuntu1.2) ...
# Selecting previously unselected package libabw-0.1-1:amd64.
# Preparing to unpack .../060-libabw-0.1-1_0.1.3-1build1_amd64.deb ...
# Unpacking libabw-0.1-1:amd64 (0.1.3-1build1) ...
# Selecting previously unselected package libapache-pom-java.
# Preparing to unpack .../061-libapache-pom-java_18-1_all.deb ...
# Unpacking libapache-pom-java (18-1) ...
# Selecting previously unselected package libbsh-java.
# Preparing to unpack .../062-libbsh-java_2.0b4-20_all.deb ...
# Unpacking libbsh-java (2.0b4-20) ...
# Selecting previously unselected package libcdr-0.1-1:amd64.
# Preparing to unpack .../063-libcdr-0.1-1_0.1.6-1build2_amd64.deb ...
# Unpacking libcdr-0.1-1:amd64 (0.1.6-1build2) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../064-libsuitesparseconfig5_1%3a5.7.1+dfsg-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.7.1+dfsg-2) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../065-libcolamd2_1%3a5.7.1+dfsg-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.7.1+dfsg-2) ...
# Selecting previously unselected package libcommons-parent-java.
# Preparing to unpack .../066-libcommons-parent-java_43-1_all.deb ...
# Unpacking libcommons-parent-java (43-1) ...
# Selecting previously unselected package libcommons-logging-java.
# Preparing to unpack .../067-libcommons-logging-java_1.2-2_all.deb ...
# Unpacking libcommons-logging-java (1.2-2) ...
# Selecting previously unselected package libe-book-0.1-1:amd64.
# Preparing to unpack .../068-libe-book-0.1-1_0.1.3-1build3_amd64.deb ...
# Unpacking libe-book-0.1-1:amd64 (0.1.3-1build3) ...
# Selecting previously unselected package libel-api-java.
# Preparing to unpack .../069-libel-api-java_3.0.0-2_all.deb ...
# Unpacking libel-api-java (3.0.0-2) ...
# Selecting previously unselected package libepubgen-0.1-1:amd64.
# Preparing to unpack .../070-libepubgen-0.1-1_0.1.1-1ubuntu2_amd64.deb ...
# Unpacking libepubgen-0.1-1:amd64 (0.1.1-1ubuntu2) ...
# Selecting previously unselected package libetonyek-0.1-1:amd64.
# Preparing to unpack .../071-libetonyek-0.1-1_0.1.9-3_amd64.deb ...
# Unpacking libetonyek-0.1-1:amd64 (0.1.9-3) ...
# Selecting previously unselected package libfreehand-0.1-1.
# Preparing to unpack .../072-libfreehand-0.1-1_0.1.2-2ubuntu1_amd64.deb ...
# Unpacking libfreehand-0.1-1 (0.1.2-2ubuntu1) ...
# Selecting previously unselected package libservlet-api-java.
# Preparing to unpack .../073-libservlet-api-java_4.0.1-2_all.deb ...
# Unpacking libservlet-api-java (4.0.1-2) ...
# Selecting previously unselected package libjsp-api-java.
# Preparing to unpack .../074-libjsp-api-java_2.3.4-2_all.deb ...
# Unpacking libjsp-api-java (2.3.4-2) ...
# Selecting previously unselected package libwebsocket-api-java.
# Preparing to unpack .../075-libwebsocket-api-java_1.1-1_all.deb ...
# Unpacking libwebsocket-api-java (1.1-1) ...
# Selecting previously unselected package libservlet3.1-java.
# Preparing to unpack .../076-libservlet3.1-java_1%3a4.0.1-2_all.deb ...
# Unpacking libservlet3.1-java (1:4.0.1-2) ...
# Selecting previously unselected package libhsqldb1.8.0-java.
# Preparing to unpack .../077-libhsqldb1.8.0-java_1.8.0.10+dfsg-10_all.deb ...
# Unpacking libhsqldb1.8.0-java (1.8.0.10+dfsg-10) ...
# Selecting previously unselected package libjuh-java.
# Preparing to unpack .../078-libjuh-java_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libjuh-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libjurt-java.
# Preparing to unpack .../079-libjurt-java_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libjurt-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libmspub-0.1-1:amd64.
# Preparing to unpack .../080-libmspub-0.1-1_0.1.4-1build3_amd64.deb ...
# Unpacking libmspub-0.1-1:amd64 (0.1.4-1build3) ...
# Selecting previously unselected package libmwaw-0.3-3:amd64.
# Preparing to unpack .../081-libmwaw-0.3-3_0.3.15-2build1_amd64.deb ...
# Unpacking libmwaw-0.3-3:amd64 (0.3.15-2build1) ...
# Selecting previously unselected package mysql-common.
# Preparing to unpack .../082-mysql-common_5.8+1.0.5ubuntu2_all.deb ...
# Unpacking mysql-common (5.8+1.0.5ubuntu2) ...
# Selecting previously unselected package libmysqlclient21:amd64.
# Preparing to unpack .../083-libmysqlclient21_8.0.37-0ubuntu0.20.04.3_amd64.deb ...
# Unpacking libmysqlclient21:amd64 (8.0.37-0ubuntu0.20.04.3) ...
# Selecting previously unselected package libodfgen-0.1-1:amd64.
# Preparing to unpack .../084-libodfgen-0.1-1_0.1.7-1ubuntu2_amd64.deb ...
# Unpacking libodfgen-0.1-1:amd64 (0.1.7-1ubuntu2) ...
# Selecting previously unselected package libpagemaker-0.0-0:amd64.
# Preparing to unpack .../085-libpagemaker-0.0-0_0.0.4-1build1_amd64.deb ...
# Unpacking libpagemaker-0.0-0:amd64 (0.0.4-1build1) ...
# Selecting previously unselected package libpq5:amd64.
# Preparing to unpack .../086-libpq5_12.18-0ubuntu0.20.04.1_amd64.deb ...
# Unpacking libpq5:amd64 (12.18-0ubuntu0.20.04.1) ...
# Selecting previously unselected package lp-solve.
# Preparing to unpack .../087-lp-solve_5.5.0.15-4build1_amd64.deb ...
# Unpacking lp-solve (5.5.0.15-4build1) ...
# Selecting previously unselected package libwps-0.4-4:amd64.
# Preparing to unpack .../088-libwps-0.4-4_0.4.10-1build1_amd64.deb ...
# Unpacking libwps-0.4-4:amd64 (0.4.10-1build1) ...
# Selecting previously unselected package libreoffice-calc.
# Preparing to unpack .../089-libreoffice-calc_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-calc (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libvisio-0.1-1:amd64.
# Preparing to unpack .../090-libvisio-0.1-1_0.1.7-1build2_amd64.deb ...
# Unpacking libvisio-0.1-1:amd64 (0.1.7-1build2) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../091-libwpd-0.10-10_0.10.3-1build1_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.3-1build1) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../092-libwpg-0.3-3_0.3.3-1build1_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.3-1build1) ...
# Selecting previously unselected package libreoffice-draw.
# Preparing to unpack .../093-libreoffice-draw_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-draw (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-impress.
# Preparing to unpack .../094-libreoffice-impress_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-impress (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-math.
# Preparing to unpack .../095-libreoffice-math_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-math (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-report-builder-bin.
# Preparing to unpack .../096-libreoffice-report-builder-bin_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-report-builder-bin (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-writer.
# Preparing to unpack .../097-libreoffice-writer_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-writer (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package python3-uno.
# Preparing to unpack .../098-python3-uno_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking python3-uno (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice.
# Preparing to unpack .../099-libreoffice_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-gnome.
# Preparing to unpack .../100-libreoffice-gnome_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-gnome (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-gtk3.
# Preparing to unpack .../101-libreoffice-gtk3_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-gtk3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libridl-java.
# Preparing to unpack .../102-libridl-java_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libridl-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libunoil-java.
# Preparing to unpack .../103-libunoil-java_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libunoil-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libunoloader-java.
# Preparing to unpack .../104-libunoloader-java_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libunoloader-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-java-common.
# Preparing to unpack .../105-libreoffice-java-common_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-java-common (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-report-builder.
# Preparing to unpack .../106-libreoffice-report-builder_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-report-builder (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-script-provider-bsh.
# Preparing to unpack .../107-libreoffice-script-provider-bsh_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-script-provider-bsh (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-script-provider-js.
# Preparing to unpack .../108-libreoffice-script-provider-js_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-script-provider-js (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-script-provider-python.
# Preparing to unpack .../109-libreoffice-script-provider-python_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-script-provider-python (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-firebird.
# Preparing to unpack .../110-libreoffice-sdbc-firebird_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-firebird (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-hsqldb.
# Preparing to unpack .../111-libreoffice-sdbc-hsqldb_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-hsqldb (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-mysql.
# Preparing to unpack .../112-libreoffice-sdbc-mysql_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-mysql (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-postgresql.
# Preparing to unpack .../113-libreoffice-sdbc-postgresql_1%3a6.4.7-0ubuntu0.20.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-postgresql (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-style-elementary.
# Preparing to unpack .../114-libreoffice-style-elementary_1%3a6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-style-elementary (1:6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-wiki-publisher.
# Preparing to unpack .../115-libreoffice-wiki-publisher_1.2.0+LibO6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-wiki-publisher (1.2.0+LibO6.4.7-0ubuntu0.20.04.10) ...
# Selecting previously unselected package libreoffice-nlpsolver.
# Preparing to unpack .../116-libreoffice-nlpsolver_0.9+LibO6.4.7-0ubuntu0.20.04.10_all.deb ...
# Unpacking libreoffice-nlpsolver (0.9+LibO6.4.7-0ubuntu0.20.04.10) ...
# Setting up fonts-sil-gentium-basic (1.102-1) ...
# Setting up mysql-common (5.8+1.0.5ubuntu2) ...
# update-alternatives: using /etc/mysql/my.cnf.fallback to provide /etc/mysql/my.cnf (my.cnf) in auto mode
# Setting up fonts-dejavu (2.37-1) ...
# Setting up libmysqlclient21:amd64 (8.0.37-0ubuntu0.20.04.3) ...
# Setting up fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Setting up libgpgmepp6:amd64 (1.13.1-7ubuntu2.2) ...
# Setting up libtommath1:amd64 (1.2.0-3ubuntu0.1) ...
# Setting up fonts-noto-extra (20200323-1build1~ubuntu20.04.1) ...
# Setting up libunoil-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libyajl2:amd64 (2.1.0-3ubuntu0.20.04.1) ...
# Setting up libuno-sal3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libpq5:amd64 (12.18-0ubuntu0.20.04.1) ...
# Setting up libel-api-java (3.0.0-2) ...
# Setting up gstreamer1.0-gtk3:amd64 (1.16.3-0ubuntu1.2) ...
# Setting up libreoffice-style-tango (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libpoppler97:amd64 (0.86.1-0ubuntu1.4) ...
# Setting up libeot0:amd64 (0.01-5) ...
# Setting up libboost-filesystem1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Setting up libboost-iostreams1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Setting up firebird3.0-common-doc (3.0.5.33220.ds4-1build2) ...
# Setting up libboost-date-time1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu5) ...
# Setting up poppler-data (0.4.9-2) ...
# Setting up fonts-crosextra-carlito (20130920-1) ...
# Setting up firebird3.0-common (3.0.5.33220.ds4-1build2) ...
# Setting up fonts-sil-gentium (20081126:1.03-2) ...
# Setting up libreoffice-style-colibre (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up fonts-liberation2 (2.1.0-1) ...
# Setting up libapache-pom-java (18-1) ...
# Setting up libwebsocket-api-java (1.1-1) ...
# Setting up libneon27-gnutls:amd64 (0.30.2-4) ...
# Setting up libfreehand-0.1-1 (0.1.2-2ubuntu1) ...
# Setting up libclucene-core1v5:amd64 (2.3.3.4+dfsg-1build1) ...
# Setting up fonts-linuxlibertine (5.3.0-4) ...
# Setting up libbsh-java (2.0b4-20) ...
# Setting up libjsp-api-java (2.3.4-2) ...
# Setting up libmhash2:amd64 (0.9.9.9-8) ...
# Setting up libmythes-1.2-0:amd64 (2:1.2.4-3build1) ...
# Setting up libxmlsec1-nss:amd64 (1.2.28-2) ...
# Setting up libexttextcat-data (3.4.5-1) ...
# Setting up libabw-0.1-1:amd64 (0.1.3-1build1) ...
# Setting up fonts-liberation (1:1.07.4-11) ...
# Setting up libservlet-api-java (4.0.1-2) ...
# Setting up libepubgen-0.1-1:amd64 (0.1.1-1ubuntu2) ...
# Setting up fonts-crosextra-caladea (20130214-2) ...
# Setting up libboost-locale1.71.0:amd64 (1.71.0-6ubuntu6) ...
# Setting up liblangtag-common (0.6.3-1) ...
# Setting up libib-util:amd64 (3.0.5.33220.ds4-1build2) ...
# Setting up libunoloader-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up fonts-noto-ui-core (20200323-1build1~ubuntu20.04.1) ...
# Setting up libwpd-0.10-10:amd64 (0.10.3-1build1) ...
# Setting up fonts-noto-core (20200323-1build1~ubuntu20.04.1) ...
# Setting up libridl-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.7.1+dfsg-2) ...
# Setting up fonts-opensymbol (2:102.11+LibO6.4.7-0ubuntu0.20.04.10) ...
# Setting up libservlet3.1-java (1:4.0.1-2) ...
# Setting up libodfgen-0.1-1:amd64 (0.1.7-1ubuntu2) ...
# Setting up libvisio-0.1-1:amd64 (0.1.7-1build2) ...
# Setting up libreoffice-style-elementary (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libwps-0.4-4:amd64 (0.4.10-1build1) ...
# Setting up libcolamd2:amd64 (1:5.7.1+dfsg-2) ...
# Setting up liborcus-0.15-0:amd64 (0.15.3-3build2) ...
# Setting up libexttextcat-2.0-0:amd64 (3.4.5-1) ...
# Setting up libmspub-0.1-1:amd64 (0.1.4-1build3) ...
# Setting up libcommons-parent-java (43-1) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu1.20.04.1) ...
# Setting up lp-solve (5.5.0.15-4build1) ...
# Setting up libcommons-logging-java (1.2-2) ...
# Setting up libcmis-0.5-5v5 (0.5.2-1ubuntu1) ...
# Setting up libpagemaker-0.0-0:amd64 (0.0.4-1build1) ...
# Setting up libmwaw-0.3-3:amd64 (0.3.15-2build1) ...
# Setting up libcdr-0.1-1:amd64 (0.1.6-1build2) ...
# Setting up liblangtag1:amd64 (0.6.3-1) ...
# Setting up libfbclient2:amd64 (3.0.5.33220.ds4-1build2) ...
# Setting up firebird3.0-utils (3.0.5.33220.ds4-1build2) ...
# Setting up libhsqldb1.8.0-java (1.8.0.10+dfsg-10) ...
# Setting up libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1build1) ...
# Setting up libwpg-0.3-3:amd64 (0.3.3-1build1) ...
# Setting up firebird3.0-server-core:amd64 (3.0.5.33220.ds4-1build2) ...
# Setting up librasqal3:amd64 (0.9.33-0.1) ...
# Setting up libetonyek-0.1-1:amd64 (0.1.9-3) ...
# Setting up libe-book-0.1-1:amd64 (0.1.3-1build3) ...
# Setting up librdf0:amd64 (1.0.17-1.1ubuntu1) ...
# Setting up libuno-salhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libuno-cppu3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libuno-purpenvhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up uno-libs-private (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libuno-cppuhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up ure (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libjurt-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-common (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libjuh-java (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-core (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-math (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-gtk3 (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-sdbc-postgresql (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-draw (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-java-common (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-base-drivers (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-wiki-publisher (1.2.0+LibO6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-sdbc-firebird (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-sdbc-mysql (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-gnome (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-impress (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-base-core (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up python3-uno (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-script-provider-bsh (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-script-provider-js (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-calc (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-base (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-sdbc-hsqldb (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-writer (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-script-provider-python (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-nlpsolver (0.9+LibO6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-report-builder-bin (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice (1:6.4.7-0ubuntu0.20.04.10) ...
# Setting up libreoffice-report-builder (1:6.4.7-0ubuntu0.20.04.10) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.14) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for shared-mime-info (1.15-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# LibreOffice installation completed successfully.
# dpkg-preconfigure: unable to re-open stdin: No such file or directory
